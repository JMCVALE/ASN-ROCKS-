# %% [markdown]
# <a href="https://colab.research.google.com/github/JMCVALE/ASN-ROCKS-/blob/main/SERIES_TEMPORAIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BIBLIOTECAS

# %%
from dateutil.parser import parse
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

import dateutil
import calendar

import matplotlib.pyplot as plt
print('✅ Bibliotecas carregadas!')
# Out:
# ✅ Bibliotecas carregadas!

# %% [markdown]
# Base de Dados contem as datas e duração das chamadas feitas por um telefone celular.
#
# As principais colunas são:
#
# - date: Data e hora da chamada
# - duration:
#     - A duração (em segundos) para cada chamada, item=call
#     - Total em MB para data, item=data
#     - numero de mensagens SMS enviadas, item=sms
# - item: evento de ocorrencia: call, sms, ou data
# - month: mês/ano da cobrança
# - network: rede móvel utilizada para cada chamada ou envio de SMS
# - network_type: mobile, international (‘world’), voicemail, landline, or other (‘special’) number.
#
# Referencia:https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/

# %% [markdown]
# ## 1. Load data Set

# %%
# !pip install gdown # ponte entre Google Drive e Python
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gdown

file_id = "1iyTAvEhMXDDmpVBdGps0z99sFzwQOZHy"

gdown.download(
    f"https://drive.google.com/uc?id={file_id}",
    "phone_data.csv",
    quiet=False
)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iyTAvEhMXDDmpVBdGps0z99sFzwQOZHy
# To: /content/phone_data.csv
# 100%|██████████| 40.6k/40.6k [00:00<00:00, 45.8MB/s]
# 'phone_data.csv'

# %%
data = pd.read_csv('phone_data.csv')
data.head(20)
# Out:
#     index            date  duration  item    month    network network_type
# 0       0  15/10/14 06:58    34.429  data  2014-11       data         data
# 1       1  15/10/14 06:58    13.000  call  2014-11   Vodafone       mobile
# 2       2  15/10/14 14:46    23.000  call  2014-11     Meteor       mobile
# 3       3  15/10/14 14:48     4.000  call  2014-11      Tesco       mobile
# 4       4  15/10/14 17:27     4.000  call  2014-11      Tesco       mobile
# 5       5  15/10/14 18:55     4.000  call  2014-11      Tesco       mobile
# 6       6  16/10/14 06:58    34.429  data  2014-11       data         data
# 7       7  16/10/14 15:01   602.000  call  2014-11      Three       mobile
# 8       8  16/10/14 15:12  1050.000  call  2014-11      Three       mobile
# 9       9  16/10/14 15:30    19.000  call  2014-11  voicemail    voicemail
# 10     10  16/10/14 16:21  1183.000  call  2014-11      Three       mobile
# 11     11  16/10/14 22:18     1.000   sms  2014-11     Meteor       mobile
# 12     12  16/10/14 22:21     1.000   sms  2014-11     Meteor       mobile
# 13     13  17/10/14 06:58    34.429  data  2014-11       data         data
# 14     14  17/10/14 10:53     1.000   sms  2014-11      Tesco       mobile
# 15     15  17/10/14 11:19     1.000   sms  2014-11      Tesco       mobile
# 16     16  17/10/14 11:20     1.000   sms  2014-11     Meteor       mobile
# 17     17  17/10/14 17:22     1.000   sms  2014-11   Vodafone       mobile
# 18     18  17/10/14 17:23     1.000   sms  2014-11   Vodafone       mobile
# 19     19  17/10/14 17:26    92.000  call  2014-11      Three       mobile

# %%
############################################################
# Converter de string para DATA
############################################################
data['date'] = data['date'].apply(dateutil.parser.parse, dayfirst=True)
data.head()
# Out:
#    index                date  duration  item    month   network network_type
# 0      0 2014-10-15 06:58:00    34.429  data  2014-11      data         data
# 1      1 2014-10-15 06:58:00    13.000  call  2014-11  Vodafone       mobile
# 2      2 2014-10-15 14:46:00    23.000  call  2014-11    Meteor       mobile
# 3      3 2014-10-15 14:48:00     4.000  call  2014-11     Tesco       mobile
# 4      4 2014-10-15 17:27:00     4.000  call  2014-11     Tesco       mobile

# %%
############################################################
# Criação das variáveis: hora, dia, mes, ano e semana
############################################################
data['hour'] = data['date'].dt.strftime('%H')
data['day'] = data['date'].dt.strftime('%d')
data['month_1'] = data['date'].dt.strftime('%m')
data['year'] = data['date'].dt.strftime('%Y')
data['week'] = data['date'].dt.strftime('%W')
data.head()
# Out:
#    index                date  duration  item    month   network network_type  \
# 0      0 2014-10-15 06:58:00    34.429  data  2014-11      data         data
# 1      1 2014-10-15 06:58:00    13.000  call  2014-11  Vodafone       mobile
# 2      2 2014-10-15 14:46:00    23.000  call  2014-11    Meteor       mobile
# 3      3 2014-10-15 14:48:00     4.000  call  2014-11     Tesco       mobile
# 4      4 2014-10-15 17:27:00     4.000  call  2014-11     Tesco       mobile
#
#   hour day month_1  year week
# 0   06  15      10  2014   41
# 1   06  15      10  2014   41
# 2   14  15      10  2014   41
# 3   14  15      10  2014   41
# 4   17  15      10  2014   41

# %%
################################################
# Plotando o gráfico da duração por data
################################################
plt.figure(figsize=(16,8))
plt.plot(data['date'],data['duration'], color='red')

# %% [markdown]
# ## 2. Summarising the DataFrame

# %%
# How many rows the dataset
data['item'].count()
# Out:
# np.int64(830)

# %%
# What was the longest phone call / data entry?
data['duration'].max()
# Out:
# 10528.0

# %%
data['duration'].min()
# Out:
# 1.0

# %%
# How many seconds of phone calls are recorded in total?
data['duration'][data['item'] == 'call'].sum()
# Out:
# np.float64(92321.0)

# %%
# How many entries are there for each month?
data['month'].value_counts()
# Out:
# month
# 2014-11    230
# 2015-01    205
# 2014-12    157
# 2015-02    137
# 2015-03    101
# Name: count, dtype: int64

# %%
# Number of non-null unique network entries
data['network'].nunique()
# Out:
# 9

# %%
data['network'].unique()
# Out:
# array(['data', 'Vodafone', 'Meteor', 'Tesco', 'Three', 'voicemail',
#        'landline', 'special', 'world'], dtype=object)

# %% [markdown]
# ## 3. Summarising Groups in the DataFrame

# %% [markdown]
# ## 3.1 DAY - Summarising and plot new variables

# %%
## Sumariza a variavel duration considerando item=call
# Intervalo de Tempo: dia
# Método de acumulação: max, min, total
data_day = data[data['item'] == 'call'].groupby(['year','month_1', 'day']).agg(
    # Get max of the duration column for each group
    max_duration=('duration', max),
    # Get min of the duration column for each group
    min_duration=('duration', min),
    # Get sum of the duration column for each group
    sum_duration=('duration', sum)
    # Get mean of the duration column for each group
    #mean_duration=('duration', )
)
# Out:
# /tmp/ipykernel_19654/2525047294.py:4: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data_day = data[data['item'] == 'call'].groupby(['year','month_1', 'day']).agg(
# /tmp/ipykernel_19654/2525047294.py:4: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data_day = data[data['item'] == 'call'].groupby(['year','month_1', 'day']).agg(
# /tmp/ipykernel_19654/2525047294.py:4: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data_day = data[data['item'] == 'call'].groupby(['year','month_1', 'day']).agg(

# %%
data_day.head()
# Out:
#                   max_duration  min_duration  sum_duration
# year month_1 day
# 2014 10      15           23.0           4.0          48.0
#              16         1183.0          19.0        2854.0
#              17          375.0           4.0         471.0
#              18         1714.0           3.0        3089.0
#              19          428.0          23.0         628.0

# %%
##############################################
# Day - Max
##############################################
# plt.figure(figsize=(16,5))
# plt.plot(list(data_day['max_duration']), 'o', color='green')
plt.figure(figsize=(16,5))
plt.plot(list(data_day['max_duration']), color='blue')

# %%
##############################################
# Day - Min
##############################################
# plt.figure(figsize=(16,5))
# plt.plot(list(data_day['min_duration']), 'o', color='green')
plt.figure(figsize=(16,5))
plt.plot(list(data_day['min_duration']), color='blue')

# %%
##############################################
# Day - Sum
##############################################
# plt.figure(figsize=(16,5))
# plt.plot(list(data_day['sum_duration']), 'o', color='green')
plt.figure(figsize=(16,5))
plt.plot(list(data_day['sum_duration']), color='blue')

# %% [markdown]
# ## 3.2 MONTH - Summarising and plot new variables

# %%
## Sumariza a variavel duration considerando item=call
# Intervalo de Tempo: mês
# Método de acumulação: max, min, total
data_month = data[data['item'] == 'call'].groupby(['year','month_1']).agg(
    # Get max of the duration column for each group
    max_duration=('duration', max),
    # Get min of the duration column for each group
    min_duration=('duration', min),
    # Get sum of the duration column for each group
    sum_duration=('duration', sum)
    # Get mean of the duration column for each group
    #mean_duration=('duration', )
)
# Out:
# /tmp/ipykernel_19654/1287514951.py:4: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data_month = data[data['item'] == 'call'].groupby(['year','month_1']).agg(
# /tmp/ipykernel_19654/1287514951.py:4: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data_month = data[data['item'] == 'call'].groupby(['year','month_1']).agg(
# /tmp/ipykernel_19654/1287514951.py:4: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data_month = data[data['item'] == 'call'].groupby(['year','month_1']).agg(

# %%
data_month.head()
# Out:
#               max_duration  min_duration  sum_duration
# year month_1
# 2014 10             1940.0           3.0       16309.0
#      11             2120.0           1.0       16780.0
#      12             1859.0           3.0       14861.0
# 2015 01             1863.0           1.0       18705.0
#      02             2328.0           2.0       11019.0

# %%
##############################################
# Month - Max
##############################################
# plt.figure(figsize=(16,5))
# plt.plot(list(data_month['max_duration']), 'o', color='green')
plt.figure(figsize=(16,5))
plt.plot(list(data_month['max_duration']), color='blue')

# %%
##############################################
# Month - Min
##############################################
# plt.figure(figsize=(16,5))
# plt.plot(list(data_month['min_duration']), 'o', color='green')
plt.figure(figsize=(16,5))
plt.plot(list(data_month['min_duration']), color='blue')

# %%
##############################################
# Month - Sum
##############################################
# plt.figure(figsize=(16,5))
# plt.plot(list(data_month['sum_duration']), 'o', color='green')
plt.figure(figsize=(16,5))
plt.plot(list(data_month['sum_duration']), color='blue')
